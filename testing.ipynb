# %%
import pandas as pd

# %%
df = pd.read_csv(r'camera_score.csv')

# %%
print(df[df['name'].duplicated()])
print(df['name'].duplicated().sum())
# Out:
#                             name  camera_score
# 89      Samsung Galaxy S22 Ultra           131
# 148     Samsung Galaxy S21 Ultra           115
# 163           Samsung Galaxy S21           111
# 164          Samsung Galaxy S21+           111
# 170                 Vivo X60 Pro           108
# 207         Xiaomi Redmi Note 14            84
# 219         Xiaomi Redmi Note 13            75
# 236         Xiaomi Redmi Note 12            63
# 239             Xiaomi Redmi 13C            60
# 279            Honor Magic6 Lite           156
# 305           Samsung Galaxy S22           120
# 325         Xiaomi Redmi Note 10           134
# 330                     Oppo A74           133
# 359      Samsung Galaxy Note 10+           113
# 362  Samsung Galaxy Note20 Ultra           136
# 391           Huawei Mate 30 Pro           124
# 393          Samsung Galaxy S10+           113
# 17
