# %%
import pandas as pd

# %%
df1 = pd.read_csv(r'full_data_1.csv')
df2 = pd.read_csv(r'full_data_2.csv')

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      977 non-null    int64
#  1   Name            977 non-null    str
#  2   Price           977 non-null    int64
#  3   Screen Size     977 non-null    float64
#  4   Display         977 non-null    int64
#  5   Chipset         977 non-null    int64
#  6   NFC             977 non-null    int64
#  7   ROM             977 non-null    float64
#  8   RAM             977 non-null    float64
#  9   Battery         977 non-null    float64
#  10  Refresh Rate    977 non-null    float64
#  11  perf_cores      977 non-null    float64
#  12  eff_cores       977 non-null    float64
#  13  perf_freq_ghz   977 non-null    float64
#  14  eff_freq_ghz    977 non-null    float64
#  15  OS_Name         977 non-null    int64
#  16  OS_Version      977 non-null    float64
# ...

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0          0
# Name                0
# Price               0
# Screen Size         0
# Display             0
# Chipset             0
# NFC                 0
# ROM                 0
# RAM                 0
# Battery             0
# Refresh Rate        0
# perf_cores          0
# eff_cores           0
# perf_freq_ghz       0
# eff_freq_ghz        0
# OS_Name             0
# OS_Version          0
# antutu_11         221
# rear_count          0
# rear_mp_max         0
# rear_f/             0
# rear_ois            0
# rear_telephoto      0
# rear_wide           0
# front_mp            0
# front_f/            0
# Camera_score      797
# gpu_family_enc      0
# PPI                 0
# SIM_total           0
# has_eSIM            0
# dtype: int64
