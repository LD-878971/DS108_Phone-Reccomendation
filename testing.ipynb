# %%
import pandas as pd
import re

# %%
df = pd.read_csv(r'data_cleaned.csv')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 726 entries, 0 to 725
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       726 non-null    int64
#  1   Name             726 non-null    str
#  2   Screen Size      726 non-null    float64
#  3   Display          726 non-null    int64
#  4   NFC              726 non-null    int64
#  5   ROM              726 non-null    float64
#  6   RAM              726 non-null    float64
#  7   Battery          726 non-null    float64
#  8   antutu_11        726 non-null    float64
#  9   clock            726 non-null    float64
#  10  gpu              726 non-null    str
#  11  OS_Name          726 non-null    int64
#  12  Brand            726 non-null    str
#  13  Refresh Rate     726 non-null    float64
#  14  total_cores      726 non-null    float64
#  15  max_freq_ghz     726 non-null    float64
#  16  min_freq_ghz     726 non-null    float64
# ...

# %%
df[df['Refresh Rate'] > 240][['Name', 'Refresh Rate']]
# Out:
#                   Name  Refresh Rate
# 290  xiaomi 17 pro max        2160.0
# 300          xiaomi 17        2160.0
# 315      xiaomi 17 pro        2160.0
